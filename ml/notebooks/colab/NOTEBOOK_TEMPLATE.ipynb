# %% [markdown]
# # MoMo-FDVS standard Colab notebook template
#
# Copy this thin wrapper only after the preceding logical milestone is complete. Put reusable behaviour in `momo_fdvs_ml`, keep outputs stripped and preserve the stop boundary.

# %%
RUN_PROFILE = "smoke"
TARGET_COMMIT = "REPLACE_WITH_PUSHED_PR12_SHA"
DRIVE_ROOT = "/content/drive/MyDrive/momo-fraud"
VM_ROOT = "/content/momo-work"
NOTEBOOK_PATH = "ml/notebooks/colab/REPLACE_WITH_NOTEBOOK.ipynb"
SEED = 20260810
assert RUN_PROFILE == "smoke"

# %%
from pathlib import Path
from momo_fdvs_ml.colab import ColabPaths
from momo_fdvs_ml.execution import ExecutionProfile

paths = ColabPaths(drive_root=Path(DRIVE_ROOT), vm_root=Path(VM_ROOT))
assert ExecutionProfile(RUN_PROFILE) is ExecutionProfile.SMOKE
layout = paths.create()
print({name: str(path) for name, path in sorted(layout.items())})

# %% [markdown]
# ## Stop boundary
#
# Replace this text with the milestone-specific human review boundary. Never continue into acquisition, locked evaluation or reportable fitting implicitly.
